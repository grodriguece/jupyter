# %% [markdown]
# # Find Table for Parameter List
# tabcustom.csv: custom tables created not included in table find analysis<br>
# make a list for each table in order to sent to sql query<br>
# 10 parameter per group<br>
# line will take table name

# %%
from datetime import date
from pathlib import Path
from pyexcelerate import Workbook
from rfpack.validatabc import validatab
from rfpack.customparamc import customparam
from rfpack.pntopdc import pntopd
from rfpack.graffullc import graffull
from rfpack.csvfrmxlsxc import xlsxfmcsv

# %%
datab = Path('C:/SQLite/20200522_sqlite.db')
pdf_file = date.today().strftime("%y%m%d") + '_Feat1ParAudit.pdf'
pdf_path = datab.parent / pdf_file
xls_file = Path(pdf_path.with_suffix('.xlsx'))
wb = Workbook()  # pyexcelerate Workbook
fndtbl = datab.parent / Path('findtable.csv')
tbcstm = datab.parent / Path('tabcustom.csv')
validatab(datab, fndtbl, tbcstm)  # locate input tab/parameters in dbabase
pnglist, sheetsdic = customparam(datab, 'tab_par')  # generates png files and create xlsx file
# rffl = 'C:/SQLite/tablasSQL.csv'  # sheets to select in xlsxsheets column
# rfflph = Path(rffl)
# clmntp = 'xlsxsheets'  # column to process in this case Total
# sheetsdic = get_sheet_details(xls_file)  # get sheet names and ids without opening xlsx file
# df = get_sheetid_bynamef(rfflph, clmntp, sheetsdic)  # xlsxsheets column from csv table file
# csvfrmxlsx(xls_file, df)  # df with sheets to be converted
pnglist1 = graffull(xls_file, 'Total', 4)  # print Total info in 4 pages, 3 regions per page
pnglist1.extend(pnglist) # review png at the beggining
pntopd(pdf_path, pnglist1, 50, 550, 500, 500)  # png to pdf
xlsxfmcsv(xls_file, sheetsdic)
# xlsxreord(xls_file, df.at[0, 'name'], 0)  # put review sheet at the beginning of the file
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\AMLEPRall.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\AMLEPRall1.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\AMLEPR3075.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\AMLEPR30751.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\AMLEPR3225.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\AMLEPR32251.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\AMLEPR626.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\AMLEPR6261.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\AMLEPR651.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\AMLEPR6511.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\ANRPRLall.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\ANRPRLall1.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IAFIM_INTRFRNCLISTall.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IAFIM_INTRFRNCLISTall1.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IAFIM_INTRFRNCLIST3075.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IAFIM_INTRFRNCLIST30751.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IAFIM_INTRFRNCLIST626.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IAFIM_INTRFRNCLIST6261.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IAFIM_INTRFRNCLIST651.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IAFIM_INTRFRNCLIST6511.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IRFIMall.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\facets\facet.py:549: PlotnineWarning: If you need more space for the x-axis tick text use ... + theme(subplots_adjust={'wspace': 0.25}). Choose an appropriate value for 'wspace'.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IRFIMall1.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IRFIMall2.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IRFIM3075.png
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\facets\facet.py:549: PlotnineWarning: If you need more space for the x-axis tick text use ... + theme(subplots_adjust={'wspace': 0.25}). Choose an appropriate value for 'wspace'.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:727: PlotnineWarning: Saving 20 x 10 in image.
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: C:\SQLite\IRFIM30751.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-f45360b75b2e> in <module>
#       7 tbcstm = datab.parent / Path('tabcustom.csv')
#       8 validatab(datab, fndtbl, tbcstm)  # locate input tab/parameters in dbabase
# ----> 9 pnglist, sheetsdic = customparam(datab, 'tab_par')  # generates png files and create xlsx file
#      10 # rffl = 'C:/SQLite/tablasSQL.csv'  # sheets to select in xlsxsheets column
#      11 # rfflph = Path(rffl)
#
# C:\ProgramData\Anaconda3\lib\site-packages\rfpack\customparamc.py in customparam(datb, tab_par)
#     189                             pngname = str(line) + str(carr) + str(j + 1) + ".png"
#     190                             pngfile = dat_dir / pngname
# --> 191                             top_plot.save(pngfile, width=20, height=10, dpi=300)
#     192                             pnglist.append(pngfile)
#     193         except sqlite3.Error as error:  # sqlite error handling.
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py in save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     745
#     746         try:
# --> 747             _save()
#     748         except Exception as err:
#     749             figure[0] and plt.close(figure[0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py in _save()
#     732         # Helper function so that we can clean up when it fails
#     733         def _save():
# --> 734             fig = figure[0] = self.draw()
#     735
#     736             # savefig ignores the figure face & edge colors
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py in draw(self, return_ggplot)
#     179         # new frames knowing that they are separate from the original.
#     180         with pd.option_context('mode.chained_assignment', None):
# --> 181             return self._draw(return_ggplot)
#     182
#     183     def _draw(self, return_ggplot=False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py in _draw(self, return_ggplot)
#     199                 self._resize_panels()
#     200                 # Drawing
# --> 201                 self._draw_layers()
#     202                 self._draw_labels()
#     203                 self._draw_breaks_and_labels()
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\ggplot.py in _draw_layers(self)
#     387         """
#     388         # Draw the geoms
# --> 389         self.layers.draw(self.layout, self.coordinates)
#     390
#     391     def _draw_breaks_and_labels(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\layer.py in draw(self, layout, coord)
#      75         for i, l in enumerate(self, start=1):
#      76             l.zorder = i
# ---> 77             l.draw(layout, coord)
#      78
#      79     def compute_aesthetics(self, plot):
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\layer.py in draw(self, layout, coord)
#     468         # At this point each layer must have the data
#     469         # that is created by the plot build process
# --> 470         self.geom.draw_layer(self.data, layout, coord, **params)
#     471
#     472     def use_defaults(self, data=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\geoms\geom.py in draw_layer(self, data, layout, coord, **params)
#     220             panel_params = layout.panel_params[ploc]
#     221             ax = layout.axs[ploc]
# --> 222             self.draw_panel(pdata, panel_params, coord, ax, **params)
#     223
#     224     def draw_panel(self, data, panel_params, coord, ax, **params):
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\geoms\geom.py in draw_panel(self, data, panel_params, coord, ax, **params)
#     255         for _, gdata in data.groupby('group'):
#     256             gdata.reset_index(inplace=True, drop=True)
# --> 257             self.draw_group(gdata, panel_params, coord, ax, **params)
#     258
#     259     @staticmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\geoms\geom_boxplot.py in draw_group(data, panel_params, coord, ax, **params)
#     176
#     177         # plot
# --> 178         geom_segment.draw_group(whiskers, panel_params,
#     179                                 coord, ax, **params)
#     180         geom_crossbar.draw_group(box, panel_params,
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\geoms\geom_segment.py in draw_group(data, panel_params, coord, ax, **params)
#      41     @staticmethod
#      42     def draw_group(data, panel_params, coord, ax, **params):
# ---> 43         data = coord.transform(data, panel_params)
#      44         data['size'] *= SIZE_FACTOR
#      45         color = to_rgba(data['color'], data['alpha'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\coords\coord_flip.py in transform(self, data, panel_params, munch)
#      31
#      32     def transform(self, data, panel_params, munch=False):
# ---> 33         data = flip_labels(data)
#      34         return coord_cartesian.transform(self, data,
#      35                                          panel_params,
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\coords\coord_flip.py in flip_labels(obj)
#      76     if hasattr(obj, 'keys'):  # dict or dataframe
#      77         sub('x', 'z')
# ---> 78         sub('y', 'x')
#      79         sub('z', 'y')
#      80     elif hasattr(obj, 'x') and hasattr(obj, 'y'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\plotnine\coords\coord_flip.py in sub(a, b)
#      72             if label.startswith(a):
#      73                 new_label = b+label[1:]
# ---> 74                 obj[new_label] = obj.pop(label)
#      75
#      76     if hasattr(obj, 'keys'):  # dict or dataframe
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in pop(self, item)
#    4359         3  monkey        NaN
#    4360         """
# -> 4361         return super().pop(item=item)
#    4362
#    4363     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in pop(self, item)
#     660     def pop(self, item: Label) -> Union["Series", Any]:
#     661         result = self[item]
# --> 662         del self[item]
#     663         if self.ndim == 2:
#     664             result._reset_cacher()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3701             # exception:
#    3702             loc = self.axes[-1].get_loc(key)
# -> 3703             self._mgr.idelete(loc)
#    3704
#    3705         # delete from the caches
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in idelete(self, indexer)
#     991             affected_start = is_deleted.nonzero()[0][0]
#     992
# --> 993         for blkno, _ in _fast_count_smallints(self.blknos[affected_start:]):
#     994             blk = self.blocks[blkno]
#     995             bml = blk.mgr_locs
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _fast_count_smallints(arr)
#    1972 def _fast_count_smallints(arr: np.ndarray) -> np.ndarray:
#    1973     """Faster version of set(arr) for sequences of small numbers."""
# -> 1974     counts = np.bincount(arr.astype(np.int_))
#    1975     nz = counts.nonzero()[0]
#    1976     return np.c_[nz, counts[nz]]
#
# <__array_function__ internals> in bincount(*args, **kwargs)
#
# KeyboardInterrupt:
